# %%
import pandas as pd 
from google.colab import files 
import io
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd 
traindata = pd.read_csv('/Users/pushparajpatel/Desktop/training_data_3.csv',encoding='latin1')
traindata
# Out:
#          Record        X1        X2        X3        X4        X5        X6  \
# 0            R1  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1            R2  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2            R3  50.95714  31.85602       NaN  13.41693  -6.57898 -18.54940
# 3            R4  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4            R5  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409
# ...         ...       ...       ...       ...       ...       ...       ...
# 119994  R119995  46.65869   4.80616  17.00909   6.84714  -6.31535  -4.18926
# 119995  R119996  44.21627  10.44396   7.00015  17.16660  -9.69167   5.79512
# 119996  R119997  46.65217  13.23733  -3.57068   4.87947  -4.28937   0.98271
# 119997  R119998  44.11805       NaN  40.55097  37.57806   3.41552 -13.49226
# 119998  R119999  44.65225 -21.91789   6.42085  20.19141  -8.97761   1.88907
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c84751b-09e5-44e3-91d2-f6aa65da3d65" name="files[]" multiple disabled />
#      <output id="result-9c84751b-09e5-44e3-91d2-f6aa65da3d65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving training_data_3.csv to training_data_3.csv

# %%
# display training data
traindata=pd.read_csv(io.StringIO(uploaded['training_data_3.csv'].decode('utf-8')))
traindata
# Out:
#          Record        X1        X2  ...        X89       X90  Response
# 0            R1  49.94357  21.47114  ...  -27.46348   2.26327      2000
# 1            R2  48.73215  18.42930  ...   58.43453  26.92061      2000
# 2            R3  50.95714  31.85602  ...   39.67068  -0.66345      2000
# 3            R4  48.24750  -1.89837  ...  199.62971  18.85382      2000
# 4            R5  50.97020  42.20998  ...   55.66926  28.74903      2000
# ...         ...       ...       ...  ...        ...       ...       ...
# 119994  R119995  46.65869   4.80616  ...  100.72679 -11.32657      2000
# 119995  R119996  44.21627  10.44396  ... -215.30166 -21.51599      2000
# 119996  R119997  46.65217  13.23733  ...   25.30261  -8.39002      2000
# 119997  R119998  44.11805       NaN  ...   12.22192   6.10469      2000
# 119998  R119999  44.65225 -21.91789  ...  362.30933  14.23708      2000
#
# [119999 rows x 92 columns]

# %%
# analyzing training data
traindata.describe()
# Out:
#                   X1             X2             X3             X4  \
# count  119998.000000  119997.000000  119997.000000  119997.000000
# mean       43.346648       1.759383       8.948489       1.089896
# std         6.081024      51.560269      34.985723      16.261491
# min         4.418500    -337.092500    -257.525600    -121.600710
# 25%        39.914347     -25.867670     -10.975170      -8.577310
# 50%        44.193360       8.877680      10.768550      -0.671840
# 75%        47.825680      36.726280      29.939820       8.703230
# max        58.196280     384.065730     268.376010     157.364670
#
#                   X5             X6             X7             X8  \
# count  119999.000000  119998.000000  119998.000000  119998.000000
# mean       -6.985119      -9.470120      -2.462140      -1.810894
# std        22.950039      12.918453      14.469946       7.928760
# min      -181.953370     -70.693420    -188.214000     -62.412130
# ...

# %%
traindata['Response'].value_counts()
# Out:
# 2000    70124
# 1900    49875
# Name: Response, dtype: int64

# %%
# count responses in each category (1900's & 2000's)
import seaborn as sns
sns.countplot(x=traindata['Response'],palette='hls')

# %%
# plot histograms for each predictor value in each category
import matplotlib.pyplot as plt
traindata.groupby('Response').hist(figsize=(9,9),color='blue')
# Out:
# Response
# 1900    [[AxesSubplot(0.125,0.820551;0.0679825x0.05944...
# 2000    [[AxesSubplot(0.125,0.820551;0.0679825x0.05944...
# dtype: object

# %%
# check for null values
traindata.isnull()
# Out:
#         Record     X1     X2     X3     X4     X5     X6     X7     X8     X9  \
# 0        False  False  False  False  False  False  False  False  False  False
# 1        False  False  False  False  False  False  False  False  False  False
# 2        False  False  False   True  False  False  False  False  False  False
# 3        False  False  False  False  False  False  False  False  False  False
# 4        False  False  False  False  False  False  False  False  False  False
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 119994   False  False  False  False  False  False  False  False  False  False
# 119995   False  False  False  False  False  False  False  False  False  False
# 119996   False  False  False  False  False  False  False  False  False  False
# 119997   False  False   True  False  False  False  False  False  False  False
# 119998   False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
# counting null values
traindata.isnull().sum()
# Out:
# Record      0
# X1          1
# X2          2
# X3          2
# X4          2
#            ..
# X87         0
# X88         2
# X89         1
# X90         0
# Response    0
# Length: 92, dtype: int64

# %%
# replace null values with mean
from sklearn.impute import SimpleImputer
a=traindata[['X90','X89','X88','X87','X86','X85','X84','X83','X82','X81','X80','X79','X78','X77','X76','X75','X74','X73','X72','X71','X70','X69','X68','X67','X66','X65','X64','X63','X62','X61','X60','X59','X58','X57','X56','X55','X54','X53','X52','X51','X50','X49','X48','X47','X46','X45','X44','X43','X42','X41','X40','X39','X38','X37','X36','X35','X34','X33','X32','X31','X30','X29','X28','X27','X26','X25','X24','X23','X22','X21','X20','X19','X18','X17','X16','X15','X14','X13','X12','X11','X10','X9','X8','X7','X6','X5','X4','X3','X2','X1']]
for k in a:
  X=pd.DataFrame(data=traindata,columns=[k])
  imputer = SimpleImputer(missing_values=np.NaN, strategy = 'mean')
  X=imputer.fit_transform(X)
  traindata[k]=X

# %%
# checking again for null values
traindata.isnull().sum()
# Out:
# Record      0
# X1          0
# X2          0
# X3          0
# X4          0
#            ..
# X87         0
# X88         0
# X89         0
# X90         0
# Response    0
# Length: 92, dtype: int64

# %%
# dropping non-predictor value columns (Record & Response)
X1=traindata.drop('Record',axis=1)

# %%
X=X1.drop('Response',axis=1)
X
# Out:
#               X1         X2         X3        X4        X5        X6  \
# 0       49.94357  21.471140  73.077500   8.74861 -17.40628 -13.09905
# 1       48.73215  18.429300  70.326790  12.94636 -10.32437 -24.83777
# 2       50.95714  31.856020   8.948489  13.41693  -6.57898 -18.54940
# 3       48.24750  -1.898370  36.297720   2.58776   0.97170 -26.21683
# 4       50.97020  42.209980  67.099640   8.46791 -15.85279 -16.81409
# ...          ...        ...        ...       ...       ...       ...
# 119994  46.65869   4.806160  17.009090   6.84714  -6.31535  -4.18926
# 119995  44.21627  10.443960   7.000150  17.16660  -9.69167   5.79512
# 119996  46.65217  13.237330  -3.570680   4.87947  -4.28937   0.98271
# 119997  44.11805   1.759383  40.550970  37.57806   3.41552 -13.49226
# 119998  44.65225 -21.917890   6.420850  20.19141  -8.97761   1.88907
#
#               X7        X8        X9       X10  ...       X81        X82  \
# ...

# %%
# naming Response column
Y=traindata.Response
#Y=traindata[:-1]
Y
# Out:
# 0         2000
# 1         2000
# 2         2000
# 3         2000
# 4         2000
#           ...
# 119994    2000
# 119995    2000
# 119996    2000
# 119997    2000
# 119998    2000
# Name: Response, Length: 119999, dtype: int64

# %%
# normalizing data
from sklearn import preprocessing
x = X.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
X_scaled = pd.DataFrame(x_scaled)
X_scaled
# Out:
#               0         1         2         3         4         5         6   \
# 0       0.846541  0.497205  0.628641  0.467260  0.370583  0.302318  0.527435
# 1       0.824014  0.492987  0.623410  0.482307  0.386532  0.240701  0.636599
# 2       0.865388  0.511606  0.506700  0.483994  0.394968  0.273709  0.597672
# 3       0.815002  0.464800  0.558704  0.445175  0.411973  0.233462  0.624592
# 4       0.865631  0.525963  0.617274  0.466254  0.374082  0.282818  0.567929
# ...          ...       ...       ...       ...       ...       ...       ...
# 119994  0.785458  0.474097  0.522027  0.460444  0.395561  0.349087  0.595085
# 119995  0.740041  0.481914  0.502995  0.497436  0.387957  0.401496  0.601375
# 119996  0.785337  0.485788  0.482894  0.453390  0.400124  0.376235  0.614563
# 119997  0.738215  0.469872  0.566792  0.570604  0.417477  0.300254  0.686420
# 119998  0.748148  0.437039  0.501893  0.508279  0.389566  0.380992  0.713230
#
# ...

# %%
# splitting data
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
#X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, stratify = traindata.Response, random_state=0)
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=.20, random_state=42)

# %%
# MODEL 1 -- Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=100)
logreg.fit(X_train, Y_train)
# Out:
# /Users/pushparajpatel/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Y_pred= logreg.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 73.87%

# %%
# Using K - FOLD VALIDATION technique to improve accuracy
# k-fold cross validation is the gold-standard for evaluating the performance of a machine learning algorithm 
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kfold = KFold(n_splits=10) 
score_cv = cross_val_score(logreg, X_scaled, Y, cv=kfold, scoring='accuracy').mean()
score_cv
# Out:
# 0.7348812748284578

# %%
import warnings
warnings.simplefilter("ignore")

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y_test, Y_pred)
print(confusion_matrix)
# Out:
# [[ 5748  4072]
#  [ 2200 11980]]

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         1900       0.72      0.59      0.65      9820
#         2000       0.75      0.84      0.79     14180
#
#     accuracy                           0.74     24000
#    macro avg       0.73      0.72      0.72     24000
# weighted avg       0.74      0.74      0.73     24000

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(Y_test, Y_pred)
lr_probs =logreg.predict_proba(X_test)
ls=lr_probs[:,1]
fpr, tpr, thresholds = roc_curve(Y_test, ls,pos_label=2)
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# PROJECT DELIVERABLE 2 STARTS HERE
# **bold text**
#
#
#
# > Indented block

# %%
#for Deliverable 2 -- Gradient Boosting
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import GradientBoostingRegressor
lr_list = [0.05, 0.075, 0.1, 0.25, 0.5, 0.75, 1]
model = GradientBoostingRegressor(n_estimators=20)
model.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=20,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
Y_hat = model.predict(X_test)
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test, Y_hat)
# Out:
# 2003.3999400046343

# %%
Y_hat
# Out:
# array([1948.15938434, 1960.76181102, 1941.20760439, ..., 1951.30458191,
#        1975.1083983 , 1937.9132358 ])

# %%
#ROC SCORE
from sklearn.metrics import roc_auc_score

roc_auc_score(Y_test, Y_hat)
# Out:
# 0.7674589149112804

# %%
from sklearn.tree import DecisionTreeClassifier
model_2 = DecisionTreeClassifier(max_depth=5)
model_2.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
Y_hat = model_2.predict(X_test)
Y_hat
# Out:
# array([2000, 2000, 1900, ..., 2000, 2000, 1900])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
confusion_matrix(Y_test,Y_hat )
accuracy_score(Y_test,Y_hat)
# Out:
# 0.6859166666666666

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_hat))
# Out:
#               precision    recall  f1-score   support
#
#         1900       0.67      0.46      0.55      9820
#         2000       0.69      0.84      0.76     14180
#
#     accuracy                           0.69     24000
#    macro avg       0.68      0.65      0.65     24000
# weighted avg       0.68      0.69      0.67     24000

# %% [markdown]
# ### Best model so far is GradientBoostingRegressor

# %%
# upload testing data
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bfee994b-abea-466d-bd26-546f849ee251" name="files[]" multiple disabled />
#      <output id="result-bfee994b-abea-466d-bd26-546f849ee251">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving testing_data_3_predictor_values.xlsx to testing_data_3_predictor_values (1).xlsx

# %%
#Converting testing data into df
Test_data = pd.read_excel('testing_data_3_predictor_values.xlsx')
Test_data
# Out:
#         Record        X1        X2        X3        X4        X5        X6  \
# 0      R120000  47.75637  12.34954  12.62224  10.10841  10.43459   4.68740
# 1      R120001  47.28407  31.06824   7.97074   1.64200   1.56642   2.42835
# 2      R120002  45.77237  -1.00232 -15.48589   6.48776   1.01942  13.62452
# 3      R120003  39.68352 -40.68292 -74.79350  13.11766 -24.09802   0.17136
# 4      R120004  39.50552 -37.15476 -53.02080  55.43929  -4.56248  28.42086
# ...        ...       ...       ...       ...       ...       ...       ...
# 11995  R131995  37.46112  39.27665 -38.57258  -8.96911 -15.05439  -5.68141
# 11996  R131996  37.79367  42.04423 -10.75373 -24.56287  34.15507 -16.58276
# 11997  R131997  46.80273  57.85899  -8.55933  -0.63979 -28.51434 -13.44704
# 11998  R131998  42.96406 -40.44653 -11.27163  25.78104  10.09483 -23.34518
# 11999  R131999  38.36815 -13.43786 -60.07063  21.04712   2.36807 -33.04219
#
# ...

# %%
#Dropping the Record column
Test_data = Test_data.drop('Record',axis=1)
Test_data
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      47.75637  12.34954  12.62224  10.10841  10.43459   4.68740  21.55039
# 1      47.28407  31.06824   7.97074   1.64200   1.56642   2.42835   7.59696
# 2      45.77237  -1.00232 -15.48589   6.48776   1.01942  13.62452  11.87908
# 3      39.68352 -40.68292 -74.79350  13.11766 -24.09802   0.17136   8.07049
# 4      39.50552 -37.15476 -53.02080  55.43929  -4.56248  28.42086  21.34691
# ...         ...       ...       ...       ...       ...       ...       ...
# 11995  37.46112  39.27665 -38.57258  -8.96911 -15.05439  -5.68141  -2.77767
# 11996  37.79367  42.04423 -10.75373 -24.56287  34.15507 -16.58276 -25.97747
# 11997  46.80273  57.85899  -8.55933  -0.63979 -28.51434 -13.44704  -8.49820
# 11998  42.96406 -40.44653 -11.27163  25.78104  10.09483 -23.34518   2.00371
# 11999  38.36815 -13.43786 -60.07063  21.04712   2.36807 -33.04219 -30.02036
#
# ...

# %%
prediction = logreg.predict(Test_data)
prediction
# Out:
# array([2000, 2000, 2000, ..., 2000, 2000, 2000])

# %%
df2 = pd.DataFrame({'Predicted': prediction})
df3 = df2.head(25)
df3
# Out:
#     Predicted
# 0        2000
# 1        2000
# 2        2000
# 3        2000
# 4        2000
# 5        2000
# 6        2000
# 7        2000
# 8        2000
# 9        2000
# 10       2000
# 11       2000
# 12       2000
# 13       2000
# 14       2000
# 15       2000
# 16       2000
# 17       2000
# 18       2000
# 19       2000
# 20       2000
# 21       2000
# 22       2000
# 23       2000
# 24       2000

# %%
df2.to_csv('Test_predictions.csv')
files.download('Test_predictions.csv')
